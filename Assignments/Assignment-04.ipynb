# %% [markdown]
# <a href="https://colab.research.google.com/github/wcj365/python-stats-dataviz/blob/master/assignments/Assignment-04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# <1> 
# Import libraries
# %matplotlib inline


import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns ; sns.set()

# %%
# <2>
# load the 2017-2018 school year file "MERGED2017_18_PP.csv" 
# Don't include all columns - too many and take up computer resources (computeing power and memory)
# Only load the following 10 columns should be loaded:
# UNITID: 
# OPEID:              
# OPEID6:            
# INSTNM:          
# CITY:                      
# ZIP:               
# ADM_RATE:           
# UGDS:              
# TUITIONFEE_IN:      

df = pd.read_csv(r"C:\Users\rahma\OneDrive\Documents\Monty Documents\Data 690 Stats\Assignment 3\MERGED2017_18_PP.csv")
important = df[['UNITID', 'OPEID', 'OPEID6', 'INSTNM', 'CITY', 'ZIP', 'ADM_RATE', 'UGDS', 'TUITIONFEE_IN']]
important
# Out:
# C:\Users\rahma\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (31,1726,1727,1728,1729,1815,1817,1823,1830,1879,1880,1881,1882,1883,1884,1885,1886,1887,1888,1889,1890,1891,1892,1893,1894,1895,1896,1897,1898,1957,1958,1959,1960,1961,1962,1963,1964,1965,1966,1967,1968,1969,1970,1971,1972,1973,1974,1975,1976) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#         UNITID    OPEID  OPEID6  \
# 0       100654   100200    1002
# 1       100663   105200    1052
# 2       100690  2503400   25034
# 3       100706   105500    1055
# 4       100724   100500    1005
# ...        ...      ...     ...
# 7107  48312404   108163    1081
# 7108  48387801  4223701   42237
# 7109  48400201  4228101   42281
# 7110  48778201  4221501   42215
# 7111  49005401  4182601   41826
#
#                                                  INSTNM              CITY  \
# ...

# %%
# <3>
# Load the scorecard file Most-Recent-Cohorts-Scorecard-Elements.csv from the link:
# https://ed-public-download.app.cloud.gov/downloads/Most-Recent-Cohorts-Scorecard-Elements.csv
# This file has thre median earnings which is not present in the previous file
# Only load the two columns:
# UNITID - This column is the unique identity for each college and will be used to join with the previous file
# MD_EARN_WNE_P10  - This column has the median earnings
df2 = pd.read_csv(r"https://ed-public-download.app.cloud.gov/downloads/Most-Recent-Cohorts-Scorecard-Elements.csv")
important2 = df2[['UNITID','MD_EARN_WNE_P10']]
important2
# Out:
#         UNITID MD_EARN_WNE_P10
# 0       100654           31000
# 1       100663           41200
# 2       100690           39600
# 3       100706           46700
# 4       100724           27700
# ...        ...             ...
# 7107  48312404             NaN
# 7108  48387801             NaN
# 7109  48400201             NaN
# 7110  48778201             NaN
# 7111  49005401             NaN
#
# [7112 rows x 2 columns]

# %%
# <4> 
# Explore this file - number of colleges, head/tail/sample etc.
# Notice this file has different number of colleges from the previous file
# This indicate they are not identical and they overlap (they don't contain the same set of colleges)
head = important2.head()
tail = important2.tail()
info = important2.info()
head
tail
info
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7112 entries, 0 to 7111
# Data columns (total 2 columns):
# UNITID             7112 non-null int64
# MD_EARN_WNE_P10    5887 non-null object
# dtypes: int64(1), object(1)
# memory usage: 111.2+ KB

# %%
# <5>
#Join the two files together to produce a third file which contain all the columns and all colleges that are common to both files

df3 = pd.merge(important, important2)
df3
# Out:
#         UNITID    OPEID  OPEID6  \
# 0       100654   100200    1002
# 1       100663   105200    1052
# 2       100690  2503400   25034
# 3       100706   105500    1055
# 4       100724   100500    1005
# ...        ...      ...     ...
# 7107  48312404   108163    1081
# 7108  48387801  4223701   42237
# 7109  48400201  4228101   42281
# 7110  48778201  4221501   42215
# 7111  49005401  4182601   41826
#
#                                                  INSTNM              CITY  \
# 0                              Alabama A & M University            Normal
# 1                   University of Alabama at Birmingham        Birmingham
# 2                                    Amridge University        Montgomery
# 3                   University of Alabama in Huntsville        Huntsville
# 4                              Alabama State University        Montgomery
# ...                                                 ...               ...
# ...

# %%
# <6>
# Explore the new file - number of colleges, head/tail/sample etc.
df3.head()
df3.tail()
# Out:
#         UNITID    OPEID  OPEID6  \
# 7107  48312404   108163    1081
# 7108  48387801  4223701   42237
# 7109  48400201  4228101   42281
# 7110  48778201  4221501   42215
# 7111  49005401  4182601   41826
#
#                                                  INSTNM              CITY  \
# 7107                   Arizona State University at Yuma              Yuma
# 7108  Bay Area Medical Academy - San Jose Satellite ...          San Jose
# 7109                        High Desert Medical College         Lancaster
# 7110                                       BCI - Malden            Malden
# 7111          Health Career Institute- Lauderdale Lakes  Lauderdale Lakes
#
#             ZIP  ADM_RATE  UGDS  TUITIONFEE_IN MD_EARN_WNE_P10
# 7107  853656900       NaN   NaN            NaN             NaN
# 7108      95113       NaN   NaN            NaN             NaN
# 7109  935340000       NaN   NaN            NaN             NaN
# 7110  021480000       NaN   NaN            NaN             NaN
# ...

# %%
# <7>
# Find out the top 100 colleges that are hardest to get in (Top 100) from this new file
df4= df3[df3["ADM_RATE"]!=0]
df4.shape
hard = df4.nsmallest(100, "ADM_RATE")
hard
# Out:
#       UNITID   OPEID  OPEID6                                     INSTNM  \
# 2978  211893  325100    3251                  Curtis Institute of Music
# 3979  243744  130500    1305                        Stanford University
# 1557  166027  215500    2155                         Harvard University
# 2302  192110  274200    2742                       The Juilliard School
# 2123  186131  262700    2627                       Princeton University
# ...      ...     ...     ...                                        ...
# 1598  167358  219900    2199                    Northeastern University
# 2581  199847  297800    2978                     Wake Forest University
# 2351  193900  278500    2785                        New York University
# 3530  228325  361600    3616  Southwestern Assemblies of God University
# 225   110583  113900    1139     California State University-Long Beach
#
#                CITY         ZIP  ADM_RATE     UGDS  TUITIONFEE_IN  \
# ...

# %%
# <8>
# Display the summary statistics of the in-state tuitions of the top 100 colleges that are hardest to get in
mean_hard = hard["ADM_RATE"].mean()
median_hard= hard["ADM_RATE"].median()
print(mean_hard)
print(median_hard)
# Out:
# 0.179126
# 0.1946

# %%
# <9>
# Display the histogram of the in-state tuitions of the top 100 colleges that are hardest to get in
InStT= hard["TUITIONFEE_IN"]
InStT

InStT.plot(kind='hist')
plt.ylabel("TUITIONFEE_IN")
plt.xlabel("ADM_RATE")
plt.title("TUITION vs ADM_RATE")
plt.show()

# %%
# <10>
# Display the summary statistics of the earning potentials of the top 100 colleges that are hardest to get in
mean2hard= hard["MD_EARN_WNE_P10"].mean()
median2hard= hard["MD_EARN_WNE_P10"].median()
print(mean2hard)
print(median2hard)

# %%
# <11>
# Display the histogram of the earning potentials of the top 100 colleges that are hardest to get in
# hard["MD_EARN_WNE_P10"]= hard['MD_EARN_WNE_P10'].map({'PrivacySuppressed':0})
hard["MD_EARN_WNE_P10"]= hard['MD_EARN_WNE_P10'].dropna()
# earnings = hard["MD_EARN_WNE_P10"]
# earnings

hard.plot(kind ='hist')
plt.ylabel("MD_EARN_WNE_P10")
plt.xlabel("ADM_RATE")
plt.title("EARNING vs ADM_RATE")
plt.show()

# %%
# <12>
# Make a scatter plot of the in-state tuition and the median graduate earnings of 
# the top 100 colleges that are hardest to get in
# using Pandas
# hard['MD_EARN_WNE_P10']
hard= hard.iloc[1:]
hard = hard.apply(pd.to_numeric, errors = "coerce")
hard.dropna()

hard["TUITIONFEE_IN"]
hard
hard.plot(kind = "scatter", y = "MD_EARN_WNE_P10", x = "TUITIONFEE_IN", color = "red")
plot.show()

# plt.scatter(hard.MD_EARN_WNE_P10, hard.TUITIONFEE_IN)
# hard.plot(kind = "scatter")
# plt.xlabel("MD_EARN_WNE_P10")
# plt.ylabel("TUITIONFEE_IN")
plt.title("TUITIONFEE vs EARNING")
# plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-65-1145f67d056e> in <module>
#      11 hard
#      12 hard.plot(kind = "scatter", y = "MD_EARN_WNE_P10", x = "TUITIONFEE_IN", color = "red")
# ---> 13 plot.show()
#      14
#      15 # plt.scatter(hard.MD_EARN_WNE_P10, hard.TUITIONFEE_IN)
#
# NameError: name 'plot' is not defined

# %%
# <13>
# Make a scatter plot of the in-state tuition and the median graduate earnings of 
# the top 100 colleges that are hardest to get in
# using Matplotlib
import math
# x = float('nan')
# math.isnan(x)
# True
# def isNaN(num):
#     return num != num
def is_nan(x):
    return (x is np.nan or x != x)

hard = df4.nsmallest(100, "ADM_RATE")
hard["TUITIONFEE_IN"]
y = hard["TUITIONFEE_IN"]
x = hard["MD_EARN_WNE_P10"]
plt.scatter(x, y)
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# hard = df4.nsmallest(100, "ADM_RATE")
# hard.plot.scatter(x = "TUITIONFEE_IN", y = "MD_EARN_WNE_P10")

# %%
# <14>
# Make a scatter plot of the in-state tuition and the median graduate earnings of 
# the top 100 colleges that are hardest to get in
# using Seaborn

hard = df4.nsmallest(100, "ADM_RATE")
ax = sns.scatterplot(x = "TUITIONFEE_IN", y = "MD_EARN_WNE_P10", data=hard)
ax

# %%
# <15> 
# Your observation/conclusion of the scatter plot (use the following Markdown cell)

# %% [markdown]
# #### Based on my observation of the scatter plot,
# #### blah, blah (are the two variable related? how?, etc)
# #### blah, blah
# #### ...
# #### blah, blah

# %%
Based on my observations of the in-state tuition vs median graduate earnings scatterplot, a correlation can not be determined
between the cost of going to a school and the potential salary after graduating from it. Schools that have lower tuition fees are equally if not more likely
to have higher salaries after graduation vs schools that have higher tuition fees. Based on the scatter plot, the higher tuition fee schools
do have high salaries post graduation, but also have a higher number of lower salaries. A reason for why both low tuition and high tuition schools are 
able to have high salaries, is because the data graphed is from a source of the 100 most difficult schools to get into. Being a difficult school to enter is
most likely the primary factor that contributese to the potential of an individuals salary, instead of the schools tuition fee.
